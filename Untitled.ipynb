# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23909 sha256=8a99f359d32b22a60b8058c9077803d395fa1966842c6f5f5eb897ad33108e64
#   Stored in directory: C:\Users\admin\AppData\Local\Temp\pip-ephem-wheel-cache-h5slm5yy\wheels\fe\87\8b\7ec24486e001d3926537f5f7801f57a74d181be25b11157983
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=4d387f970107d0ed0dbc42d5a717ccc02084c9774431ff3681d8972031591b86
#   Stored in directory: C:\Users\admin\AppData\Local\Temp\pip-ephem-wheel-cache-h5slm5yy\wheels\ae\25\47\4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
# Successfully built yfinance multitasking
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
from datetime import datetime

# %%
scg = yf.Ticker("SCG.AX")

# %%
scg.info
# Out:
# {'zip': '2000',
#  'sector': 'Real Estate',
#  'fullTimeEmployees': 2427,
#  'longBusinessSummary': 'Scentre Group (ASX Code: SCG) is the owner and operator of Westfield in Australia and New Zealand with interests in 42 Westfield Living Centres, encompassing approximately 12,000 outlets.',
#  'city': 'Sydney',
#  'phone': '61 2 9358 7000',
#  'state': 'NSW',
#  'country': 'Australia',
#  'companyOfficers': [],
#  'website': 'http://www.scentregroup.com',
#  'maxAge': 1,
#  'address1': '85 Castlereagh Street',
#  'fax': '61 2 9028 8500',
#  'industry': 'REIT—Retail',
#  'ebitdaMargins': 0,
#  'profitMargins': -1.7258501,
#  'grossMargins': 0.73004997,
#  'operatingCashflow': 684600000,
#  'revenueGrowth': -0.187,
#  'operatingMargins': 0.69435,
#  'ebitda': None,
#  'targetLowPrice': None,
#  'recommendationKey': 'none',
#  'grossProfits': 1578600000,
#  'freeCashflow': -1855262464,
#  'targetMedianPrice': None,
#  'currentPrice': 2.56,
#  'earningsGrowth': None,
# ...

# %%
hist1 = scg.history(period="max")
hist1.plot(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data = yf.download (
    tickers = 'SCG.AX CHC.AX LLC.AX SGP.AX DXS.AX MGR.AX LIC.AX AVJ.AX MEA.AX HPI.AX',
    period ='10y',
    interval='1d',
    auto_adjust = True,
    threads = True,
    proxy = None,
    groupby="ticker"
)["Close"]
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
data.head()
# Out:
#               AVJ.AX    CHC.AX    DXS.AX  HPI.AX    LIC.AX    LLC.AX  MEA.AX  \
# Date
# 2011-08-22  0.262269  0.961408  2.707846     NaN  0.901199  5.332018     NaN
# 2011-08-23       NaN  0.958404  2.743475     NaN  0.942163  5.454280     NaN
# 2011-08-24       NaN  0.961408  2.796920     NaN  0.983127  5.447487     NaN
# 2011-08-25       NaN  1.009478  2.779105     NaN  0.901199  5.562959     NaN
# 2011-08-26  0.262269  1.057549  2.814735     NaN  0.983127  5.359187     NaN
#
#               MGR.AX    SCG.AX    SGP.AX
# Date
# 2011-08-22  0.643534  1.407354  1.531054
# 2011-08-23  0.655851  1.430810  1.563400
# 2011-08-24  0.665088  1.454266  1.531054
# 2011-08-25  0.674325  1.477722  1.579573
# 2011-08-26  0.680484  1.465994  1.536445

# %%
# data.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_retuns =data.pct_change()

# %%
stock_retuns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>
